# %%
import numpy as np

n_control = 62568
converted_control = 3343
cr_control = (converted_control / n_control) * 100

n_test = 62649
converted_test = 3506
cr_test = (converted_test / n_test) * 100

count = np.array([converted_test, converted_control])
nobs = np.array([n_test, n_control])

print(f" Конверсія контрольної групи: {cr_control:.2f}%")
print(f" Конверсія тестової групи:    {cr_test:.2f}%")
print(f" Отримане значення p-value:   {p_val:.4f}")

if p_val < 0.05:
    print(" Виснововк: результатт статистично значущий, фіча працює.")
else:
    print("Висновок: резкльтат випадковий, фіча не дала ефекту.")

plt.show()
# Out:
#  Конверсія контрольної групи: 5.34%
#  Конверсія тестової групи:    5.60%
#  Отримане значення p-value:   0.0488
#  Виснововк: результатт статистично значущий, фіча працює.
